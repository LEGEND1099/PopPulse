# %% [markdown]
# # Inspect 2018-2019 train occupancy
#
# Load the daily Excel files, inspect the schema, and confirm the candidate columns before feature engineering.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.append(str(PROJECT_ROOT / 'src'))

from load_data import load_excel_folder
from clean_train import detect_train_columns, clean_train_dataframe

# %%
raw_folder = PROJECT_ROOT / 'data' / 'raw' / 'train_2018_2019_daily'
df_raw = load_excel_folder(str(raw_folder))
print('Shape:', df_raw.shape)
print('Columns:', df_raw.columns.tolist())
print('Loaded files:', len(df_raw.attrs.get('source_files', [])))
df_raw.head()

# %%
detected = detect_train_columns(df_raw)
detected

# %%
df_clean, metadata = clean_train_dataframe(df_raw)
print(metadata)
df_clean.head()

# %%
output_path = PROJECT_ROOT / 'data' / 'interim' / 'train_2018_clean.parquet'
df_clean.to_parquet(output_path, index=False)
print(f'Saved cleaned parquet to {output_path}')
